# %%
import torch

# %%
out_logits = torch.tensor([[0.1, 0.9],[0.8, 0.2]])
targets = torch.tensor([0, 1])
targets.shape
# Out:
# torch.Size([2])

# %%
targets.unsqueeze(-1)
# Out:
# tensor([[0],
#         [1]])

# %%
out_logits.gather(dim=-1, index=targets.unsqueeze(-1))
# Out:
# tensor([[0.1000],
#         [0.2000]])

# %%
logsumexp = torch.logsumexp(input=out_logits, dim=-1, keepdim=True)
logsumexp
# Out:
# tensor([[1.2711],
#         [1.2375]])
